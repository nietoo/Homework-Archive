# %% [raw]
# # Машинное обучение, ФКН ВШЭ
#
# ## Практическое задание 3. Градиентный спуск своими руками
#
# ### Общая информация
# Дата выдачи: 05.10.2020
#
# Мягкий дедлайн: 01:59MSK 19.10.2020 (за каждый день просрочки снимается 1 балл)
#
# Жесткий дедлайн: 01:59MSK 22.10.2020

# %% [markdown]
# ### О задании
#
# В данном задании необходимо реализовать обучение линейной регрессии с помощью различных вариантов градиентного спуска.
#
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов + 2 балла бонус.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
# Также оценка может быть снижена за плохо читаемый код и плохо считываемые диаграммы.
#
# Все ответы должны сопровождаться кодом или комментариями о том, как они были получены.
#
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно найти на странице курса. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-03-gd-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# **Оценка**: ...

# %% [markdown]
# Напомним, что на лекциях и семинарах мы разбирали некоторые подходы к оптимизации функционалов по параметрам. В частности, был рассмотрен градиентный спуск и различные подходы к его реализации — стохастический, метод импульса и другие. В качестве модели у нас будет выступать линейная регрессия.
#
# В этом домашнем задании вам предстоит реализовать 4 различных вариации градиентного спуска, написать свою реализацию линейной регресии, сравнить методы градиентного спуска между собой на реальных данных и разобраться как подбирать гиперпараметры для этих методов.

# %% [markdown]
# ## Задание 1. Реализация градиентного спуска (3.5 балла)

# %% [markdown]
# В этом задании вам предстоит написать собственные реализации различных подходов к градиентному спуску с опорой на подготовленные шаблоны в файле  `utils.py`:
#
# **Задание 1.1. (0.5 балла)** Полный градиентный спуск **GradientDescent**:
#
# $$
#     w_{k + 1} = w_{k} - \eta_{k} \nabla_{w} Q(w_{k}).
# $$
#
# **Задание 1.2. (1 балл)** Стохастический градиентный спуск **StochasticDescent**:
#
# $$
#     w_{k + 1} = w_{k} - \eta_{k} \nabla_{w} q_{i_{k}}(w_{k}).
# $$
#
# $\nabla_{w} q_{i_{k}}(w_{k}) \,$ - это оценка градиента по одному объекту, выбранному случайно.
#
# **Задание 1.3. (1 балл)** Метод Momentum **MomentumDescent**:
#
# $$
#     h_0 = 0, \\
#     h_{k + 1} = \alpha h_{k} + \eta_k \nabla_{w} Q(w_{k}), \\
#     w_{k + 1} = w_{k} - h_{k + 1}.
# $$
#
# **Задание 1.4. (1 балл)** Метод Adaptive gradient algorithm **Adagrad**:
#
# $$
#     G_0 = 0, \\
#     G_{k + 1} = G_{k} + \left(\nabla_{w} Q(w_{k})\right) ^ 2, \\
#     w_{k + 1} = w_{k} - \dfrac{\eta_k}{\sqrt{\varepsilon + G_{k}}} \nabla_{w} Q(w_{k}).
# $$
#
#
# Во всех вышеназванных методах мы будем использовать следующую формулу для длины шага:
#
# $$
#     \eta_{k} = \lambda \left(\dfrac{s_0}{s_0 + k}\right)^p
# $$
# На практике достаточно настроить параметр $\lambda$, а остальным выставить параметры по умолчанию: $s_0 = 1, \, p = 0.5.$

# %% [markdown]
# Мы будем использовать функцию потерь MSE:
#
# $$
#     Q(w) = \dfrac{1}{\ell} \sum\limits_{i=1}^{\ell} (a_w(x_i) - y_i)^2
# $$
#
# Все вычисления должны быть векторизованы.

# %% [markdown]
# ## Задание 2. Реализация линейной регресии (1.5 балла)

# %% [markdown]
# В этом задании вам предстоит написать свою реализацию линейной регресии, обучаемой с использованием градиентного спуска, с опорой на подготовленные шаблоны в файле `utils.py` - **LinearRegression**.
#
# Необходимо соблюдать следующие условия:
#
# * Все вычисления должны быть векторизованы.
# * Циклы средствами python допускаются только для итераций градиентного спуска.
# * В качестве критерия останова необходимо использовать (одновременно):
#     * Квадрат евклидовой нормы разности весов на двух соседних итерациях меньше `tolerance`.
#     * Достижение максимального числа итераций `max_iter`.
# * Чтобы проследить за сходимостью оптимизационного процесса будем использовать `loss_history`, в нём будем хранить значения функции потерь для каждой итерации, начиная с нулевой (до первого шага).
# * Инициализировать веса нужно нулевым вектором или из нормального $\mathcal{N}(0, 1)$ распределения (тогда нужно зафиксировать seed).

# %% [markdown]
# ## Задание 3. Проверка кода (0 баллов)

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

import numpy as np

from utils import (
    Adagrad,
    GradientDescent,
    MomentumDescent,
    StochasticDescent,
)
from utils import LinearRegression

# %%
num_objects = 1000
dimension = 50

X = np.random.rand(num_objects, dimension)
y = np.random.rand(num_objects)

lambda_ = 1e-2
w0 = np.zeros(dimension)

max_iter = 10000
tolerance = 0

# %%
# GradientDescent

descent = GradientDescent(lambda_ = lambda_, w0 = w0)

gradient = descent.calc_gradient(X, y)

assert gradient.shape[0] == dimension, 'Gradient failed'

diff = descent.step(X, y, 0)

assert diff.shape[0] == dimension, 'Weights failed'

# %%
# StochasticDescent

descent = StochasticDescent(lambda_ = lambda_, w0 = w0)

gradient = descent.calc_gradient(X, y)

assert gradient.shape[0] == dimension, 'Gradient failed'

diff = descent.step(X, y, 0)

assert diff.shape[0] == dimension, 'Weights failed'

# %%
# MomentumDescent

descent = MomentumDescent(lambda_ = lambda_, w0 = w0)

gradient = descent.calc_gradient(X, y)

assert gradient.shape[0] == dimension, 'Gradient failed'

diff = descent.step(X, y, 0)

assert diff.shape[0] == dimension, 'Weights failed'

# %%
# Adagrad

descent = Adagrad(lambda_ = lambda_, w0 = w0)

gradient = descent.calc_gradient(X, y)

assert gradient.shape[0] == dimension, 'Gradient failed'

diff = descent.step(X, y, 0)

assert diff.shape[0] == dimension, 'Weights failed'

# %%
# LinearRegression

regression = LinearRegression(
    descent = StochasticDescent(lambda_ = lambda_, w0 = w0, batch_size = 2),
    tolerance = tolerance,
    max_iter = max_iter
)

regression.fit(X, y)

assert len(regression.loss_history) == max_iter, 'Loss history failed'
print(regression.loss_history)

prediction = regression.predict(X)

assert prediction.shape[0] == num_objects, 'Predict failed'
# Out:
# 0
# 0.34661788697353324
# 1
# 0.2753865870187011
# 2
# 0.27194153884643013
# 3
# 0.22872856044425385
# 4
# 0.19158373848097768
# * **Adagrad**: **https://contest.yandex.ru/contest/19551/run-report/36676846/**
# * **LinearRegression**: **https://contest.yandex.ru/contest/19551/run-report/36868518/**

# %% [markdown]
# ## Задание 4. Работа с данными (1 балл)

# %% [markdown]
# Мы будем использовать датасет объявлений по продаже машин на немецком Ebay. В задаче предсказания целевой переменной для нас будет являться цена.
# Для дальнейшей работы сделайте следующее:
# * Проведите разумную предобработку данных.
# * Замените целевую переменную на её логарифм.
# * Разделите данные на обучающую, валидационную и тестовую выборки в отношении 3:1:1.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv("autos.txt")
backup = data.copy()

# %%
data["dateCreated"] = pd.to_datetime(data["dateCreated"])
data["lastSeen"] = pd.to_datetime(data["lastSeen"])

# %%
data['log_price'] = data['price'].apply(np.log1p)
plt.hist(data['price'])
plt.title('Гистограмма цен')
plt.show()
plt.hist(data['log_price'])
plt.title('Гистограмма логарифмов цен')
plt.show()

# %%
# Объединим редкие значения в один признак "Other"

print(data.groupby('fuelType').count()['price'])

data['fuelType'] = data['fuelType'].mask(data['fuelType'].map(data['fuelType'].value_counts(normalize=True)) < 0.01, 'Other')
print(data.groupby('fuelType').count()['price'])
# Out:
# fuelType
# andere         53
# benzin     159581
# cng           429
# diesel      83841
# elektro        52
# hybrid        198
# lpg          3718
# Name: price, dtype: int64
# fuelType
# Other        732
# benzin    159581
# diesel     83841
# lpg         3718
# Name: price, dtype: int64

# %%
#Переведём значения gearbox и notRepairedDamage в {0; 1}

data['gearbox'] = data['gearbox'].transform(lambda x: 1 if x == 'manuell' else 0)
data['notRepairedDamage'] = data['notRepairedDamage'].transform(lambda x: 1 if x == 'ja' else 0)
print(data.dtypes)
# Out:
# brand                          object
# model                          object
# vehicleType                    object
# gearbox                         int64
# fuelType                       object
# notRepairedDamage               int64
# powerPS                         int64
# kilometer                       int64
# yearOfRegistration              int64
# monthOfRegistration             int64
# dateCreated            datetime64[ns]
# lastSeen               datetime64[ns]
# postalCode                      int64
# price                           int64
# log_price                     float64
# dtype: object

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='monthOfRegistration', y="log_price", data=data)

#Видно, что зависимость минимальная, можем избавиться от признака

data = data.drop(columns=['monthOfRegistration'])

# %%
#С почтовыми индексами лучше работать как с категориями; однако, сейчас их слишком много. Объединим их по региону.

data['postalCode'] = data['postalCode'].transform(lambda x: str(x // 10000))

# %%
#Дропнем lastseen, т.к. это уж точно ни на что не влияет

data = data.drop(columns = ['lastSeen'])

# %%
first_created = data['dateCreated'].unique().min()
data['dateCreated'] = (data['dateCreated'] - first_created).dt.days
print(data['dateCreated'].unique())
# Out:
# [363 377 381 378 372 384 367 366 369 373 358 359 364 353 355 354 380 371
#  375 361 368 376 326 351 357 356 374 362 379 360 382 365 370 352 349 347
#  350 383 300 341 344   0 345 337 346 327 338 227 336 343 332 323 335 348
#  261 310 314 319 330 322 339 296 329 340 242 324 342 313 288 168 237 282
#  249 306 331 320 328 260 140 333 238 325 315 293 334 317 304 294 303 301
#  233 312 321 208 311 143 299 305 316 283 285 309 318 272 235 292 173]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


X = data.drop(columns=['price', 'log_price'])
y = data['log_price']

numeric = X.select_dtypes([np.number]).columns
scaler = StandardScaler()
X[numeric] = scaler.fit_transform(X[numeric])


X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=413)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=413)
print(X_train.shape[0] / X.shape[0], X_test.shape[0] / X.shape[0], X_val.shape[0] / X.shape[0])
# Out:
# 0.5999991931319391 0.19999838626387814 0.2000024206041828

# %% [markdown]
# ## Задание 5. Сравнение методов градиентного спуска (2 балла)

# %% [markdown]
# В этом задании вам предстоит сравнить методы градиентного спуска на подготовленных вами данных из предыдущего задания.
#
# * **Задание 5.1. (1.5 балла)** Подберите по валидационной выборке наилучшую длину $\lambda$ шага для каждого метода. Для этого можно сделать перебор по логарифмической сетке, так как нас интересует скорее порядок величины, нежели её точное значение. Сравните качество методов по метрикам MSE и R^2 на обучающей и тестовой выборках, сравните количество итераций до сходимости. Все параметры кроме $\lambda$ стоит выставить равным значениям по умолчанию.
#
# * **Задание 5.2. (0.5 балла)** Постройте график зависимости значения функции ошибки от номера итерации (все методы на одном графике).
#
# Посмотрите на получившиеся результаты. Сравните методы между собой.

# %%
w0 = np.zeros(X_train.shape[1])

# descents = {GradientDescent(lambda_ = lb, w0 = w0),
#             StochasticDescent(lambda_ = lb, w0 = w0, batch_size=2),
#             MomentumDescent(lambda_ = lb, w0 = w0),
#             Adagrad(lambda_ = lb, w0 = w0)}

lambdas = np.logspace(-4, 2, 5)
optimal_lambdas = [-1 for x in range(4)]

# %%
from math import inf
tolerance = 0
min = inf
max_iter = 100
for lambda_ in lambdas:
    regression = LinearRegression(
        descent = GradientDescent(lambda_ = lambda_, w0 = w0),
        tolerance = tolerance,
        max_iter = max_iter
    )
    
    regression.fit(X_val, y_val)
    if (regression.loss_history[-1] < min):
        min = regression.loss_history[-1]
        optimal_lambdas[0] = lambda_
# Out:
# C:\Users\danbu\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: overflow encountered in square
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
min = inf
for lambda_ in lambdas:
    regression = LinearRegression(
        descent = StochasticDescent(lambda_ = lambda_, w0 = w0, batch_size=10),
        tolerance = tolerance,
        max_iter = max_iter
    )

    regression.fit(X_val, y_val)
    if (regression.loss_history[-1] < min):
        min = regression.loss_history[-1]
        optimal_lambdas[1] = lambda_

# %%
min = inf
for lambda_ in lambdas:
    regression = LinearRegression(
        descent = MomentumDescent(lambda_ = lambda_, w0 = w0),
        tolerance = tolerance,
        max_iter = max_iter
    )

    regression.fit(X_val, y_val)
    if (regression.loss_history[-1] < min):
        min = regression.loss_history[-1]
        optimal_lambdas[2] = lambda_

# %%
min = inf
for lambda_ in lambdas:
    regression = LinearRegression(
        descent = Adagrad(lambda_ = lambda_, w0 = w0),
        tolerance = tolerance,
        max_iter = max_iter
    )

    regression.fit(X_val, y_val)
    if (regression.loss_history[-1] < min):
        min = regression.loss_history[-1]
        optimal_lambdas[3] = lambda_

# %%
optimal_lambdas_backup = optimal_lambdas.copy()
print(optimal_lambdas)
# Out:
# [3.1622776601683795, 0.1, 3.1622776601683795, 3.1622776601683795]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

descents = [GradientDescent(lambda_ = optimal_lambdas[0], w0 = w0), #синий
            StochasticDescent(lambda_ = optimal_lambdas[1], w0 = w0, batch_size=2), #желтый
            MomentumDescent(lambda_ = optimal_lambdas[2], w0 = w0), #зеленый
            Adagrad(lambda_ = optimal_lambdas[3], w0 = w0), #красный
           ]

tolerance = 1e-2

i = 0

iters = [0 for x in range(4)]
mse_train = [0 for x in range(4)]
r2_train = [0 for x in range(4)]
mse_test = [0 for x in range(4)]
r2_test = [0 for x in range(4)]
loss_history = [[] for x in range(4)]

for descent in descents:
    regression = LinearRegression(
        descent = descent,
        tolerance = tolerance,
        max_iter = 1000
    )
    
    regression.fit(X_train, y_train)
    
    iters[i] = regression.break_iter
    
    y_train_pred = regression.predict(X_train)
    mse_train[i] = mean_squared_error(y_train, y_train_pred)
    r2_train[i] = r2_score(y_train, y_train_pred)
    
    y_test_pred = regression.predict(X_test)
    mse_test[i] = mean_squared_error(y_test, y_test_pred)
    r2_test[i] = r2_score(y_test, y_test_pred)
    
    loss_history[i] = regression.loss_history    
    
    i += 1

# %%
loc = ['GradientDescent',
      'StochasticDescent',
      'MomentumDescent',
      'Adagrad']

plot = sns.barplot(x=loc, y=iters)
plot.figure.set_size_inches(15, 10)
plt.ylabel("Количество итераций до сходимости")
plt.show()
plot = sns.barplot(x=loc, y=mse_test)
plot.figure.set_size_inches(15, 10)
plt.ylabel("MSE метрика")
plt.show()
plot = sns.barplot(x=loc, y=r2_test)
plot.figure.set_size_inches(15, 10)
plt.ylabel("R^2 метрика")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.yscale('log') 
for i in range(4):
    ax = plt.plot(loss_history[i], label = loc[i])
plt.legend()
plt.show()

# %% [markdown]
# ## Задание 6. Сходимость стохастического градиентного спуска в зависимости от размера батча (1 балл)

# %% [markdown]
# В этом задании вам предстоит исследовать влияние размера батча на работу стохастического градиентного спуска.
#
# * Сделайте по несколько запусков (например, k) стохастического градиентного спуска на обучающей выборке для каждого размера батча из списка. Замерьте время и количество итераций до сходимости. Посчитайте среднее и дисперсию этих значений для каждого размера батча.
# * Постройте график зависимости количества шагов до сходимости от размера батча.
# * Постройте график зависимости времени до сходимости от размера батча.
#
# Посмотрите на получившиеся результаты. Какие выводы можно сделать про подбор размера батча для стохастического градиентного спуска?
#
# Используя бОльшие батчи, жертвуем скоростью на каждом шаге, но получаем более точные результаты, ввиду чего сходимости достигаем за меньшее количество шагов. Батчи нужно подбирать разумно, слишком большие - слишком медленно будем шагать, слишком маленькие - слишком много будем шагать.

# %%
from time import time

batch_sizes = np.arange(5, 500, 10)
k = 6
j = 0

tolerance = 1e-1

times = [[0 for x in range(k)] for y in range(len(batch_sizes))]
iterations = [[0 for x in range(k)] for y in range(len(batch_sizes))]

for batch_size in batch_sizes:
    for i in range(k):
        start_time = time()
        regression = LinearRegression(
            descent = StochasticDescent(lambda_ = optimal_lambdas[1], w0 = w0, batch_size=batch_size),
            tolerance = tolerance,
            max_iter = 1000
        )
        regression.fit(X_train, y_train)
        times[j][i] = time() - start_time
        iterations[j][i] = regression.break_iter
    j += 1

# %%
print('times:')
times = np.array(times)

means = np.mean(times, axis=1)
stds = np.std(times, axis=1)

print('batch_size mean std')
for i in range(len(batch_sizes)):
    print(batch_sizes[i], means[i], stds[i])

plt.plot(batch_sizes, means)
plt.show()
    
print('-----------------------')
print('iterations:')    
    
iterations = np.array(iterations)
means = np.mean(iterations, axis=1)
stds = np.std(iterations, axis=1)

print('batch_size mean std')
for i in range(len(batch_sizes)):
    print(batch_sizes[i], means[i], stds[i])
    
plt.plot(batch_sizes, means)
plt.show()
# Out:
# times:
# batch_size mean std
# 5 10.169968684514364 1.864078052903894
# 15 9.244942506154379 1.2137325913106758
# 25 8.430786490440369 0.7008693720524092
# 35 7.5660990079243975 0.4277638381901675
# 45 7.962040106455485 0.5299164424128009
# 55 7.562608361244202 0.40928530676408303
# 65 7.774043003718059 0.30971259365922565
# 75 7.503599524497986 0.17999329983065254
# 85 7.4276357889175415 0.19867932734321664
# 95 7.573911428451538 0.3586629549319028
# 105 7.4376093943913775 0.3792232184651008
# 115 7.381592392921448 0.29778518655986314
# 125 7.45423165957133 0.32172173646359353
# 135 7.512242833773295 0.2840943174542003
# 145 7.45788848400116 0.5549163728548562
# 155 7.645054300626119 0.455412093435476
# 165 7.444756825764974 0.314652659198573
# 175 7.249113321304321 0.22995455837355344
# 185 7.313940167427063 0.274812318070817
# 195 7.243628223737081 0.39162514187463265
# 205 7.520886301994324 0.2990960738436448
# 215 7.250941872596741 0.3302005671282462
# 225 7.2592529853185015 0.31453615771015087
# 235 7.319259126981099 0.2779657737058349
# 245 7.323581099510193 0.29458928884980634
# 255 7.320921142896016 0.28134485131976295
# 265 7.401705503463745 0.1931969969688743
# 275 7.207225203514099 0.1680441357124689
# 285 7.3297310670216875 0.15817872449282513
# 295 7.327736655871074 0.14397211323961376
# 305 7.3293986320495605 0.2761660463231375
# 315 7.263242324193318 0.012114498222334125
# 325 7.198415954907735 0.15580219080766533
# 335 7.345355749130249 0.15266247190922277
# 345 7.269558588663737 0.014175011933172539
# 355 7.293827096621196 0.03952401347053854
# 365 7.273880481719971 0.01413572888620211
# 375 7.275708913803101 0.0168211619931024
# 385 7.276540080706279 0.02484682422578191
# 395 7.2090539534886675 0.15782599429524494
# 405 7.207557797431946 0.14575998196212311
# 415 7.236646850903829 0.15937759802866222
# 425 7.305130283037822 0.24759656554286094
# 435 7.301307002703349 0.01112732161913422
# 445 7.247949918111165 0.15622740645254465
# 455 7.245123982429504 0.1587503103932191
# 465 7.237644036610921 0.14921923631744305
# 475 7.248781204223633 0.14520275959194653
# 485 7.320921103159587 0.013634806065158501
# 495 7.242797017097473 0.14614641940057016
# -----------------------
# iterations:
# batch_size mean std
# 5 24.333333333333332 4.642796092394707
# 15 22.0 3.0550504633038935
# 25 20.0 1.7320508075688772
# 35 17.833333333333332 1.0671873729054748
# 45 18.833333333333332 1.3437096247164249
# 55 17.833333333333332 1.0671873729054748
# 65 18.333333333333332 0.7453559924999298
# 75 17.666666666666668 0.4714045207910317
# 85 17.5 0.5
# 95 17.833333333333332 0.8975274678557508
# 105 17.5 0.9574271077563381
# 115 17.333333333333332 0.7453559924999298
# 125 17.5 0.7637626158259734
# 135 17.666666666666668 0.7453559924999298
# 145 17.5 1.3844373104863459
# 155 18.0 1.1547005383792515
# 165 17.5 0.7637626158259734
# 175 17.0 0.5773502691896257
# 185 17.166666666666668 0.6871842709362768
# 195 17.0 1.0
# 205 17.666666666666668 0.7453559924999298
# 215 17.0 0.816496580927726
# 225 17.0 0.816496580927726
# 235 17.166666666666668 0.6871842709362768
# 245 17.166666666666668 0.6871842709362768
# 255 17.166666666666668 0.6871842709362768
# 265 17.333333333333332 0.4714045207910317
# 275 16.833333333333332 0.3726779962499649
# 285 17.166666666666668 0.3726779962499649
# 295 17.166666666666668 0.3726779962499649
# 305 17.166666666666668 0.6871842709362768
# 315 17.0 0.0
# 325 16.833333333333332 0.3726779962499649
# 335 17.166666666666668 0.3726779962499649
# 345 17.0 0.0
# 355 17.0 0.0
# 365 17.0 0.0
# 375 17.0 0.0
# 385 17.0 0.0
# 395 16.833333333333332 0.3726779962499649
# 405 16.833333333333332 0.3726779962499649
# 415 16.833333333333332 0.3726779962499649
# 425 17.0 0.5773502691896257
# 435 17.0 0.0
# 445 16.833333333333332 0.3726779962499649
# 455 16.833333333333332 0.3726779962499649
# 465 16.833333333333332 0.3726779962499649
# 475 16.833333333333332 0.3726779962499649
# 485 17.0 0.0
# 495 16.833333333333332 0.3726779962499649

# %% [markdown]
# ## Задание 7. Регуляризация (1 балл)

# %% [markdown]
# В этом задании вам предстоит исследовать влияние регуляризации на работу различных методов градиентного спуска. (Напомним, регуляризация - это добавка к функции потерь, которая штрафует за норму весов). Мы будем использовать l2 регуляризацию, таким образом функция потерь приобретает следующий вид:
#
# $$
#     Q(w) = \dfrac{1}{\ell} \sum\limits_{i=1}^{\ell} (a_w(x_i) - y_i)^2 + \dfrac{1}{2} \| w \|^2
# $$

# %% [markdown]
# Допишите классы **GradientDescentReg**, **StochasticDescentReg**, **MomentumDescentReg**, **AdagradReg** в файле `utils.py`. Мы будем использовать тот же самый класс для линейной регрессии, так как для сравнения методов с регуляризацией и без неё нам нужна только MSE часть функции потерь.

# %% [markdown]
# Найдите по валидационной выборке лучшие параметры обучения с регуляризацией. Сравните для каждого метода результаты на тестовой выборке по метрикам MSE и R^2 с регуляризацией и без регуляризации. Постройте для каждого метода график со значениями функции потерь MSE с регуляризацией и без регуляризации.

# %% [markdown]
# Посмотрите на получившиеся результаты. Какие можно сделать выводы, как регуляризация влияет на сходимость? Чем вы можете объяснить это?

# %%
# %autoreload 2

from utils import (
    AdagradReg,
    GradientDescentReg,
    MomentumDescentReg,
    StochasticDescentReg,
)

# YOUR CODE:

# %% [markdown]
# ## Задание 8. Бонус — Реализация метода SAG (2 балла)

# %% [markdown]
# В качестве бонуса вам будет следующее задание - напишите собственную реализацию стохастического градиентного спуска по методу SAG в файле `utils.py`. Подробнее прочитать про SAG можно [здесь](https://arxiv.org/pdf/1309.2388.pdf).

# %% [markdown]
# Сравните свою реализацию метода SAG с обычным полным градиентным спуском на наших данных. Проведите сравнение аналогично заданию 5. Что вы можете сказать про сходимость этого метода?

# %%
# YOUR CODE:

# %% [markdown]
# Вставьте картинку или видео, описывающие ваш опыт выполнения этого задания.
